# %% [markdown]
# ![Python](https://img.shields.io/badge/python-3.9-blue)
# ![Status: Pending Migration](https://img.shields.io/badge/status-pending%20migration-orange)
#
# <a id="table-of-contents"></a>
# # 🧾 Text Cleaning & Parsing
# - [🔍 Tokenization](#tokenization)
# - [🧼 Text Cleaning](#text-cleaning)
# - [🛑 Stopwords Removal](#stopwords)
# - [🔁 Lemmatization vs Stemming](#lemmatization-vs-stemming)
# - [🧠 POS Tagging & Named Entity Recognition](#pos-ner)
# - [🔗 Dependency Parsing & Chunking](#dependency-parsing)
# - [🧪 Edge Cases & Text Cleaning Tips](#edge-cases)
# ___

# %% [markdown]
# <a id="tokenization"></a>
# # 🔍 Tokenization

# %% [markdown]
# #### 🧱 Word Tokenization
# <a id="word-tokenization"></a>

# %% [markdown]
# #### ✂️ Sentence Tokenization
# <a id="sentence-tokenization"></a>

# %% [markdown]
# [Back to the top](#table-of-contents)
# ___

# %% [markdown]
# <a id="text-cleaning"></a>
# # 🧼 Text Cleaning

# %% [markdown]
# #### 🔤 Lowercasing and Normalization
# <a id="lowercasing"></a>

# %% [markdown]
# #### ✨ Punctuation & Special Character Removal
# <a id="punctuation-removal"></a>

# %% [markdown]
# #### 🧪 Regex Based Cleaning
# <a id="regex-cleaning"></a>

# %% [markdown]
# [Back to the top](#table-of-contents)
# ___

# %% [markdown]
# <a id="stopwords"></a>
# # 🛑 Stopwords Removal

# %% [markdown]
# #### 📚 Using NLTK/Spacy Stopword Lists
# <a id="builtin-stopwords"></a>

# %% [markdown]
# #### 🧰 Custom Stopword Handling
# <a id="custom-stopwords"></a>

# %% [markdown]
# [Back to the top](#table-of-contents)
# ___

# %% [markdown]
# <a id="lemmatization-vs-stemming"></a>
# # 🔁 Lemmatization vs Stemming

# %% [markdown]
# #### 🌱 Stemming (Porter, Snowball)
# <a id="stemming"></a>

# %% [markdown]
# #### 🍃 Lemmatization (WordNet, spaCy)
# <a id="lemmatization"></a>

# %% [markdown]
# [Back to the top](#table-of-contents)
# ___

# %% [markdown]
# <a id="pos-ner"></a>
# # 🧠 POS Tagging & Named Entity Recognition

# %% [markdown]
# #### 🏷️ POS Tagging
# <a id="pos-tagging"></a>

# %% [markdown]
# #### 🧾 Named Entity Recognition (NER)
# <a id="ner"></a>

# %% [markdown]
# [Back to the top](#table-of-contents)
# ___

# %% [markdown]
# <a id="dependency-parsing"></a>
# # 🔗 Dependency Parsing & Chunking

# %% [markdown]
# #### 🕸️ Dependency Parsing
# <a id="dependency"></a>

# %% [markdown]
# #### 🧱 Phrase Chunking (Noun Phrases etc.)
# <a id="chunking"></a>

# %% [markdown]
# [Back to the top](#table-of-contents)
# ___
